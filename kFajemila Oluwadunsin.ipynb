# %%
import math
import matplotlib.pyplot as plt
# %matplotlib inline
x_axis = []
y_axis = []
for V in range(168):
    x = 2.8*10**-4
    Xd = x*math.sqrt(1-(-V/0.6))
    C = 1414845000/Xd
    F = 1/(2*math.pi*math.sqrt(5*10**-9*C))
    x_axis.append(-V)
    value_y = F#math.sqrt(i/(4*(math.pi**2 *(5*10**-9)*(8.1056*10**-10))))
    y_axis.append(value_y)

plt.ylabel('Frequency(Hz)')
plt.xlabel('Voltage(V)')
plt.title('Question 1e')
plt.plot(x_axis,y_axis)
